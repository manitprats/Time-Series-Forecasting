# %% [markdown]
# <a href="https://colab.research.google.com/github/manitprats/Time-Series-Forecasting/blob/main/LSTM_Time_series_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
# load the dataset
dataframe = read_csv('/content/drive/MyDrive/Data/AirPassengers.csv', usecols=[1])
plt.plot(dataframe)

# %%
#Convert pandas dataframe to numpy array
dataset = dataframe.values
dataset = dataset.astype('float32') #COnvert values to float

#LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %%
#We cannot use random way of splitting dataset into train and test as
#the sequence of events is important for time series.
#So let us take first 60% values for train and the remaining 1/3 for testing
# split into train and test sets
train_size = int(len(dataset) * 0.66)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# We cannot fit the model like we normally do for image processing where we have
#X and Y. We need to transform our data into something that looks like X and Y values.
# This way it can be trained on a sequence rather than indvidual datapoints. 
# Let us convert into n number of columns for X where we feed sequence of numbers
#then the final column as Y where we provide the next number in the sequence as output.
# So let us convert an array of values into a dataset matrix

#seq_size is the number of previous time steps to use as 
#input variables to predict the next time period.

#creates a dataset where X is the number of passengers at a given time (t, t-1, t-2...) 
#and Y is the number of passengers at the next time (t + 1).

def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)

# %%
seq_size = 10  # Number of time steps to look back 
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)



print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (84, 10)
# Shape of test set: (38, 10)

# %%
#Stacked LSTM with 1 hidden dense layer
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(None, seq_size)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(32))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
#
model.summary()
print('Train...')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, None, 50)          12200
#
#  lstm_4 (LSTM)               (None, 50)                20200
#
#  dense_4 (Dense)             (None, 32)                1632
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 34,065
# Trainable params: 34,065
# Non-trainable params: 0
# _________________________________________________________________
# Train...

# %%
model.fit(trainX, trainY, validation_data=(testX, testY),
          verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 3/3 - 4s - loss: 0.0672 - val_loss: 0.3626 - 4s/epoch - 1s/step
# Epoch 2/100
# 3/3 - 0s - loss: 0.0529 - val_loss: 0.3173 - 50ms/epoch - 17ms/step
# Epoch 3/100
# 3/3 - 0s - loss: 0.0412 - val_loss: 0.2758 - 48ms/epoch - 16ms/step
# Epoch 4/100
# 3/3 - 0s - loss: 0.0316 - val_loss: 0.2370 - 57ms/epoch - 19ms/step
# Epoch 5/100
# 3/3 - 0s - loss: 0.0240 - val_loss: 0.2005 - 68ms/epoch - 23ms/step
# Epoch 6/100
# 3/3 - 0s - loss: 0.0191 - val_loss: 0.1666 - 65ms/epoch - 22ms/step
# Epoch 7/100
# 3/3 - 0s - loss: 0.0163 - val_loss: 0.1370 - 70ms/epoch - 23ms/step
# Epoch 8/100
# 3/3 - 0s - loss: 0.0151 - val_loss: 0.1145 - 63ms/epoch - 21ms/step
# Epoch 9/100
# 3/3 - 0s - loss: 0.0150 - val_loss: 0.0997 - 57ms/epoch - 19ms/step
# Epoch 10/100
# 3/3 - 0s - loss: 0.0155 - val_loss: 0.0910 - 52ms/epoch - 17ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 0.0155 - val_loss: 0.0876 - 50ms/epoch - 17ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 0.0151 - val_loss: 0.0884 - 63ms/epoch - 21ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 0.0141 - val_loss: 0.0896 - 65ms/epoch - 22ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 0.0135 - val_loss: 0.0914 - 53ms/epoch - 18ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 0.0126 - val_loss: 0.0889 - 66ms/epoch - 22ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 0.0120 - val_loss: 0.0859 - 49ms/epoch - 16ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 0.0115 - val_loss: 0.0788 - 67ms/epoch - 22ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 0.0107 - val_loss: 0.0684 - 63ms/epoch - 21ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 0.0101 - val_loss: 0.0546 - 79ms/epoch - 26ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 0.0092 - val_loss: 0.0430 - 58ms/epoch - 19ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 0.0084 - val_loss: 0.0327 - 69ms/epoch - 23ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 0.0076 - val_loss: 0.0254 - 55ms/epoch - 18ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 0.0069 - val_loss: 0.0210 - 69ms/epoch - 23ms/step
# Epoch 24/100
# 3/3 - 0s - loss: 0.0061 - val_loss: 0.0193 - 47ms/epoch - 16ms/step
# Epoch 25/100
# 3/3 - 0s - loss: 0.0056 - val_loss: 0.0194 - 50ms/epoch - 17ms/step
# Epoch 26/100
# 3/3 - 0s - loss: 0.0051 - val_loss: 0.0218 - 69ms/epoch - 23ms/step
# Epoch 27/100
# 3/3 - 0s - loss: 0.0046 - val_loss: 0.0253 - 53ms/epoch - 18ms/step
# Epoch 28/100
# 3/3 - 0s - loss: 0.0043 - val_loss: 0.0314 - 67ms/epoch - 22ms/step
# Epoch 29/100
# 3/3 - 0s - loss: 0.0040 - val_loss: 0.0370 - 62ms/epoch - 21ms/step
# Epoch 30/100
# 3/3 - 0s - loss: 0.0039 - val_loss: 0.0449 - 52ms/epoch - 17ms/step
# Epoch 31/100
# 3/3 - 0s - loss: 0.0037 - val_loss: 0.0509 - 56ms/epoch - 19ms/step
# Epoch 32/100
# 3/3 - 0s - loss: 0.0036 - val_loss: 0.0582 - 65ms/epoch - 22ms/step
# Epoch 33/100
# 3/3 - 0s - loss: 0.0037 - val_loss: 0.0687 - 51ms/epoch - 17ms/step
# Epoch 34/100
# 3/3 - 0s - loss: 0.0036 - val_loss: 0.0647 - 56ms/epoch - 19ms/step
# Epoch 35/100
# 3/3 - 0s - loss: 0.0035 - val_loss: 0.0562 - 50ms/epoch - 17ms/step
# Epoch 36/100
# 3/3 - 0s - loss: 0.0036 - val_loss: 0.0595 - 75ms/epoch - 25ms/step
# Epoch 37/100
# 3/3 - 0s - loss: 0.0035 - val_loss: 0.0582 - 52ms/epoch - 17ms/step
# Epoch 38/100
# 3/3 - 0s - loss: 0.0034 - val_loss: 0.0609 - 49ms/epoch - 16ms/step
# Epoch 39/100
# 3/3 - 0s - loss: 0.0034 - val_loss: 0.0588 - 68ms/epoch - 23ms/step
# Epoch 40/100
# 3/3 - 0s - loss: 0.0033 - val_loss: 0.0608 - 59ms/epoch - 20ms/step
# Epoch 41/100
# 3/3 - 0s - loss: 0.0033 - val_loss: 0.0551 - 53ms/epoch - 18ms/step
# Epoch 42/100
# 3/3 - 0s - loss: 0.0032 - val_loss: 0.0462 - 76ms/epoch - 25ms/step
# Epoch 43/100
# 3/3 - 0s - loss: 0.0032 - val_loss: 0.0442 - 51ms/epoch - 17ms/step
# Epoch 44/100
# 3/3 - 0s - loss: 0.0031 - val_loss: 0.0441 - 47ms/epoch - 16ms/step
# Epoch 45/100
# 3/3 - 0s - loss: 0.0030 - val_loss: 0.0486 - 70ms/epoch - 23ms/step
# Epoch 46/100
# 3/3 - 0s - loss: 0.0030 - val_loss: 0.0487 - 63ms/epoch - 21ms/step
# Epoch 47/100
# 3/3 - 0s - loss: 0.0030 - val_loss: 0.0391 - 64ms/epoch - 21ms/step
# Epoch 48/100
# 3/3 - 0s - loss: 0.0029 - val_loss: 0.0372 - 59ms/epoch - 20ms/step
# Epoch 49/100
# 3/3 - 0s - loss: 0.0028 - val_loss: 0.0418 - 52ms/epoch - 17ms/step
# Epoch 50/100
# 3/3 - 0s - loss: 0.0030 - val_loss: 0.0503 - 66ms/epoch - 22ms/step
# Epoch 51/100
# 3/3 - 0s - loss: 0.0028 - val_loss: 0.0390 - 62ms/epoch - 21ms/step
# Epoch 52/100
# 3/3 - 0s - loss: 0.0027 - val_loss: 0.0290 - 61ms/epoch - 20ms/step
# Epoch 53/100
# 3/3 - 0s - loss: 0.0028 - val_loss: 0.0272 - 46ms/epoch - 15ms/step
# Epoch 54/100
# 3/3 - 0s - loss: 0.0027 - val_loss: 0.0352 - 51ms/epoch - 17ms/step
# Epoch 55/100
# 3/3 - 0s - loss: 0.0026 - val_loss: 0.0405 - 47ms/epoch - 16ms/step
# Epoch 56/100
# 3/3 - 0s - loss: 0.0026 - val_loss: 0.0386 - 51ms/epoch - 17ms/step
# Epoch 57/100
# 3/3 - 0s - loss: 0.0026 - val_loss: 0.0295 - 48ms/epoch - 16ms/step
# Epoch 58/100
# 3/3 - 0s - loss: 0.0025 - val_loss: 0.0288 - 54ms/epoch - 18ms/step
# Epoch 59/100
# 3/3 - 0s - loss: 0.0025 - val_loss: 0.0294 - 65ms/epoch - 22ms/step
# Epoch 60/100
# 3/3 - 0s - loss: 0.0024 - val_loss: 0.0333 - 63ms/epoch - 21ms/step
# Epoch 61/100
# 3/3 - 0s - loss: 0.0024 - val_loss: 0.0377 - 63ms/epoch - 21ms/step
# Epoch 62/100
# 3/3 - 0s - loss: 0.0024 - val_loss: 0.0336 - 66ms/epoch - 22ms/step
# Epoch 63/100
# 3/3 - 0s - loss: 0.0023 - val_loss: 0.0225 - 70ms/epoch - 23ms/step
# Epoch 64/100
# 3/3 - 0s - loss: 0.0023 - val_loss: 0.0233 - 62ms/epoch - 21ms/step
# Epoch 65/100
# 3/3 - 0s - loss: 0.0023 - val_loss: 0.0297 - 65ms/epoch - 22ms/step
# Epoch 66/100
# 3/3 - 0s - loss: 0.0022 - val_loss: 0.0276 - 68ms/epoch - 23ms/step
# Epoch 67/100
# 3/3 - 0s - loss: 0.0021 - val_loss: 0.0225 - 47ms/epoch - 16ms/step
# Epoch 68/100
# 3/3 - 0s - loss: 0.0021 - val_loss: 0.0217 - 58ms/epoch - 19ms/step
# Epoch 69/100
# 3/3 - 0s - loss: 0.0021 - val_loss: 0.0216 - 48ms/epoch - 16ms/step
# Epoch 70/100
# 3/3 - 0s - loss: 0.0020 - val_loss: 0.0235 - 48ms/epoch - 16ms/step
# Epoch 71/100
# 3/3 - 0s - loss: 0.0020 - val_loss: 0.0282 - 69ms/epoch - 23ms/step
# Epoch 72/100
# 3/3 - 0s - loss: 0.0020 - val_loss: 0.0243 - 47ms/epoch - 16ms/step
# Epoch 73/100
# 3/3 - 0s - loss: 0.0019 - val_loss: 0.0210 - 66ms/epoch - 22ms/step
# Epoch 74/100
# 3/3 - 0s - loss: 0.0019 - val_loss: 0.0199 - 64ms/epoch - 21ms/step
# Epoch 75/100
# 3/3 - 0s - loss: 0.0019 - val_loss: 0.0218 - 61ms/epoch - 20ms/step
# Epoch 76/100
# 3/3 - 0s - loss: 0.0019 - val_loss: 0.0247 - 45ms/epoch - 15ms/step
# Epoch 77/100
# 3/3 - 0s - loss: 0.0019 - val_loss: 0.0222 - 61ms/epoch - 20ms/step
# Epoch 78/100
# 3/3 - 0s - loss: 0.0018 - val_loss: 0.0160 - 71ms/epoch - 24ms/step
# Epoch 79/100
# 3/3 - 0s - loss: 0.0019 - val_loss: 0.0141 - 46ms/epoch - 15ms/step
# Epoch 80/100
# 3/3 - 0s - loss: 0.0019 - val_loss: 0.0196 - 48ms/epoch - 16ms/step
# Epoch 81/100
# 3/3 - 0s - loss: 0.0018 - val_loss: 0.0199 - 50ms/epoch - 17ms/step
# Epoch 82/100
# 3/3 - 0s - loss: 0.0018 - val_loss: 0.0150 - 44ms/epoch - 15ms/step
# Epoch 83/100
# 3/3 - 0s - loss: 0.0017 - val_loss: 0.0145 - 60ms/epoch - 20ms/step
# Epoch 84/100
# 3/3 - 0s - loss: 0.0017 - val_loss: 0.0174 - 45ms/epoch - 15ms/step
# Epoch 85/100
# 3/3 - 0s - loss: 0.0017 - val_loss: 0.0159 - 50ms/epoch - 17ms/step
# Epoch 86/100
# 3/3 - 0s - loss: 0.0017 - val_loss: 0.0133 - 51ms/epoch - 17ms/step
# Epoch 87/100
# 3/3 - 0s - loss: 0.0017 - val_loss: 0.0174 - 55ms/epoch - 18ms/step
# Epoch 88/100
# 3/3 - 0s - loss: 0.0017 - val_loss: 0.0168 - 50ms/epoch - 17ms/step
# Epoch 89/100
# 3/3 - 0s - loss: 0.0016 - val_loss: 0.0120 - 56ms/epoch - 19ms/step
# Epoch 90/100
# 3/3 - 0s - loss: 0.0017 - val_loss: 0.0126 - 67ms/epoch - 22ms/step
# Epoch 91/100
# 3/3 - 0s - loss: 0.0016 - val_loss: 0.0175 - 66ms/epoch - 22ms/step
# Epoch 92/100
# 3/3 - 0s - loss: 0.0016 - val_loss: 0.0157 - 46ms/epoch - 15ms/step
# Epoch 93/100
# 3/3 - 0s - loss: 0.0016 - val_loss: 0.0133 - 50ms/epoch - 17ms/step
# Epoch 94/100
# 3/3 - 0s - loss: 0.0015 - val_loss: 0.0119 - 51ms/epoch - 17ms/step
# Epoch 95/100
# 3/3 - 0s - loss: 0.0016 - val_loss: 0.0120 - 73ms/epoch - 24ms/step
# Epoch 96/100
# 3/3 - 0s - loss: 0.0016 - val_loss: 0.0143 - 54ms/epoch - 18ms/step
# Epoch 97/100
# 3/3 - 0s - loss: 0.0015 - val_loss: 0.0107 - 47ms/epoch - 16ms/step
# Epoch 98/100
# 3/3 - 0s - loss: 0.0015 - val_loss: 0.0110 - 64ms/epoch - 21ms/step
# Epoch 99/100
# 3/3 - 0s - loss: 0.0015 - val_loss: 0.0124 - 53ms/epoch - 18ms/step
# Epoch 100/100
# 3/3 - 0s - loss: 0.0015 - val_loss: 0.0114 - 49ms/epoch - 16ms/step

# %%
# make predictions

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step

# %%
# invert predictions back to prescaled values
#This is to compare with original input values
#SInce we used minmaxscaler we can now use scaler.inverse_transform
#to invert the transformation.
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))

testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 19.90 RMSE
# Test Score: 55.26 RMSE

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset. 
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
