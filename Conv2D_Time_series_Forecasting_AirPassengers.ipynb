# %% [markdown]
# <a href="https://colab.research.google.com/github/manitprats/Time-Series-Forecasting/blob/main/Conv2D_Time_series_Forecasting_AirPassengers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
# load the dataset
dataframe = read_csv('/content/drive/MyDrive/Data/AirPassengers.csv', usecols=[1])
plt.plot(dataframe)

# %%
#Convert pandas dataframe to numpy array
dataset = dataframe.values
dataset = dataset.astype('float32') #COnvert values to float

#LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1)) #Also try QuantileTransformer
dataset = scaler.fit_transform(dataset)

# %%
#We cannot use random way of splitting dataset into train and test as
#the sequence of events is important for time series.
#So let us take first 60% values for train and the remaining 1/3 for testing
# split into train and test sets
train_size = int(len(dataset) * 0.66)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# We cannot fit the model like we normally do for image processing where we have
#X and Y. We need to transform our data into something that looks like X and Y values.
# This way it can be trained on a sequence rather than indvidual datapoints. 
# Let us convert into n number of columns for X where we feed sequence of numbers
#then the final column as Y where we provide the next number in the sequence as output.
# So let us convert an array of values into a dataset matrix

#seq_size is the number of previous time steps to use as 
#input variables to predict the next time period.

#creates a dataset where X is the number of passengers at a given time (t, t-1, t-2...) 
#and Y is the number of passengers at the next time (t + 1).

def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)

# %%
seq_size = 10  # Number of time steps to look back 
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)



print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (84, 10)
# Shape of test set: (38, 10)

# %%
#ConvLSTM
#The layer expects input as a sequence of two-dimensional images, 
#therefore the shape of input data must be: [samples, timesteps, rows, columns, features]

trainX = trainX.reshape((trainX.shape[0], 1, 1, 1, seq_size))
testX = testX.reshape((testX.shape[0], 1, 1, 1, seq_size))

# %%
model = Sequential()
model.add(ConvLSTM2D(filters=64, kernel_size=(1,1), activation='relu', input_shape=(1, 1, 1, seq_size)))
model.add(Flatten())
model.add(Dense(32))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
#print('Train...')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, 1, 1, 64)          19200
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 21,313
# Trainable params: 21,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(trainX, trainY, validation_data=(testX, testY),
          verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 3/3 - 3s - loss: 0.0518 - val_loss: 0.2415 - 3s/epoch - 967ms/step
# Epoch 2/100
# 3/3 - 0s - loss: 0.0346 - val_loss: 0.1691 - 52ms/epoch - 17ms/step
# Epoch 3/100
# 3/3 - 0s - loss: 0.0206 - val_loss: 0.1095 - 34ms/epoch - 11ms/step
# Epoch 4/100
# 3/3 - 0s - loss: 0.0119 - val_loss: 0.0637 - 37ms/epoch - 12ms/step
# Epoch 5/100
# 3/3 - 0s - loss: 0.0074 - val_loss: 0.0344 - 36ms/epoch - 12ms/step
# Epoch 6/100
# 3/3 - 0s - loss: 0.0070 - val_loss: 0.0214 - 51ms/epoch - 17ms/step
# Epoch 7/100
# 3/3 - 0s - loss: 0.0086 - val_loss: 0.0183 - 34ms/epoch - 11ms/step
# Epoch 8/100
# 3/3 - 0s - loss: 0.0092 - val_loss: 0.0183 - 37ms/epoch - 12ms/step
# Epoch 9/100
# 3/3 - 0s - loss: 0.0084 - val_loss: 0.0198 - 43ms/epoch - 14ms/step
# Epoch 10/100
# 3/3 - 0s - loss: 0.0069 - val_loss: 0.0236 - 36ms/epoch - 12ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 0.0060 - val_loss: 0.0289 - 53ms/epoch - 18ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 0.0055 - val_loss: 0.0330 - 36ms/epoch - 12ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 0.0057 - val_loss: 0.0345 - 35ms/epoch - 12ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 0.0056 - val_loss: 0.0321 - 54ms/epoch - 18ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 0.0053 - val_loss: 0.0278 - 42ms/epoch - 14ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 0.0049 - val_loss: 0.0226 - 35ms/epoch - 12ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 0.0046 - val_loss: 0.0188 - 37ms/epoch - 12ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 0.0044 - val_loss: 0.0170 - 54ms/epoch - 18ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 0.0042 - val_loss: 0.0163 - 35ms/epoch - 12ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 0.0040 - val_loss: 0.0160 - 37ms/epoch - 12ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 0.0039 - val_loss: 0.0158 - 36ms/epoch - 12ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 0.0037 - val_loss: 0.0156 - 36ms/epoch - 12ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 0.0035 - val_loss: 0.0153 - 33ms/epoch - 11ms/step
# Epoch 24/100
# 3/3 - 0s - loss: 0.0034 - val_loss: 0.0149 - 36ms/epoch - 12ms/step
# Epoch 25/100
# 3/3 - 0s - loss: 0.0033 - val_loss: 0.0149 - 33ms/epoch - 11ms/step
# Epoch 26/100
# 3/3 - 0s - loss: 0.0032 - val_loss: 0.0151 - 46ms/epoch - 15ms/step
# Epoch 27/100
# 3/3 - 0s - loss: 0.0031 - val_loss: 0.0155 - 33ms/epoch - 11ms/step
# Epoch 28/100
# 3/3 - 0s - loss: 0.0031 - val_loss: 0.0158 - 33ms/epoch - 11ms/step
# Epoch 29/100
# 3/3 - 0s - loss: 0.0030 - val_loss: 0.0156 - 32ms/epoch - 11ms/step
# Epoch 30/100
# 3/3 - 0s - loss: 0.0029 - val_loss: 0.0151 - 34ms/epoch - 11ms/step
# Epoch 31/100
# 3/3 - 0s - loss: 0.0029 - val_loss: 0.0148 - 35ms/epoch - 12ms/step
# Epoch 32/100
# 3/3 - 0s - loss: